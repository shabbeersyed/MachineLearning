# %% [markdown]
# <!--BOOK_INFORMATION-->
# <img align="left" style="padding-right:10px;" src="https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/figures/PDSH-cover-small.png?raw=1">
#
# *This notebook contains an excerpt from the [Python Data Science Handbook](http://shop.oreilly.com/product/0636920034919.do) by Jake VanderPlas; the content is available [on GitHub](https://github.com/jakevdp/PythonDataScienceHandbook).*
#
# *The text is released under the [CC-BY-NC-ND license](https://creativecommons.org/licenses/by-nc-nd/3.0/us/legalcode), and code is released under the [MIT license](https://opensource.org/licenses/MIT). If you find this content useful, please consider supporting the work by [buying the book](http://shop.oreilly.com/product/0636920034919.do)!*

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# <!--NAVIGATION-->
# < [Data Manipulation with Pandas](03.00-Introduction-to-Pandas.ipynb) | [Contents](Index.ipynb) | [Data Indexing and Selection](03.02-Data-Indexing-and-Selection.ipynb) >
#
# <a href="https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/03.01-Introducing-Pandas-Objects.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory"></a>

# %% [markdown]
# # Introducing Pandas Objects

# %% [markdown]
# At the very basic level, Pandas objects can be thought of as enhanced versions of NumPy structured arrays in which the rows and columns are identified with labels rather than simple integer indices.
# As we will see during the course of this chapter, Pandas provides a host of useful tools, methods, and functionality on top of the basic data structures, but nearly everything that follows will require an understanding of what these structures are.
# Thus, before we go any further, let's introduce these three fundamental Pandas data structures: the ``Series``, ``DataFrame``, and ``Index``.
#
# We will start our code sessions with the standard NumPy and Pandas imports:

# %% [markdown]
# # 1. Create

# %% [markdown]
# 1.1 Create from CSV

# %% [markdown]
# 1.2 Create from a Dictionary

# %% [markdown]
# Dictionary holds key:value pair. Key-Value is provided in the dictionary to make it more optimized. Think Press 1 for Billing, Press 2 for Customer Service.

# %% [markdown]
# These are just two methods to create a dataframe. There are many file types to read from using Pandas.

# %% [markdown]
# # 2. Read

# %% [markdown]
# 2.1 Show Top 5 and Bottom 5 Rows

# %%
 #First five rows of data

# %%
 #First 10 rows, but we can pass a different number (parameter) to the head function

# %%
 #Last five rows

# %%
 #Bottom 15 rows. Or whatever number we want to pass as the parameter

# %% [markdown]
# 2.2 Show Columns and Data Type

# %%
 #displays all of the column names

# %%
 #review the data types

# %% [markdown]
# 2.3 Summary Statistics

# %% [markdown]
# 2.4 Filtering on Columns

# %%
#Single column

# %%
#Space in the name

# %%
#grab two columns, pass an array

# %%
#Find unique values

# %% [markdown]
# 2.5 Filtering on Rows

# %%
#Let's review our rows

# %%
#conditional filtering

# %%
#multiple filters using concatation

# %% [markdown]
# 2.6 Indexing with iLoc

# %%
#Instead of using specific values, we are going to be using integers
#Look at 15th row

# %%
#two different parameters (row,column)

# %%
#slicing
#look at a subset of the data

# %% [markdown]
# 2.7 Indexing with loc

# %%
#We can set an index
#copy our data

#replace index without having to copy the dataframe again

# %%
#let's look at it

# %%
#let's look at coffer

# %% [markdown]
# 2.8 Sugar question

# %%
#multiple filters using concatation

# %% [markdown]
# # 3. Update

# %% [markdown]
# 3.1 Dropping Rows

# %%
#preprocessing - rows that have null or nothing

# %%
#drop rows that have missing values. Pandas use na for a missing value

# %%
#Let's look again

# %% [markdown]
# 3.2 Dropping Columns

# %%
#Axis 1 = columns, 0 = rows (the default)

# %% [markdown]
# 3.3 Creating Calculated Columns

# %%
#convert to a numeric value

# %%
#Can use math
#let's add two columns

# %% [markdown]
# 3.4 Updating an Entire Column

# %% [markdown]
# 3.5 Updating a single value

# %%
#first row, last column

# %% [markdown]
# 3.6 Condition based Updating using Apply

# %% [markdown]
# # 4.Delete/Output

# %% [markdown]
# 4.1 Output to CSV

# %% [markdown]
# 4.2 Delete a dataframe

# %% [markdown]
# MatPlotLib allows us to quickly create charts and graphs.

# %% [markdown]
# Main function
